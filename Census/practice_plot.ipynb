# %%
import numpy as np
import pandas as pd

# %%
import csv
import matplotlib.pyplot as plt
import os

# %%
userhome = os.path.expanduser('~')
csvfile= userhome + r'/Desktop/load_forecasting/loadinsight/demographics/demographics.csv'
with open(csvfile,'r')as f:
    data = csv.reader(f)
    for row in data:
        print(row)
# Out:
# ['Zipcode', 'City', 'Latitude', 'Longitude', 'Population', 'Density', 'Occupancy', 'Value', 'Income']
# ['59421', 'Cascade MT', '47.2', '-111.7', '1831', '3', '0.56', '193.8', '52.2']
# ['59601', 'Helena MT', '46.5', '-112.1', '29283', '212', '0.94', '199.9', '52.2']
# ['59715', 'Bozeman MT', '45.7', '-111.0', '31567', '68', '0.89', '328.5', '47.9']
# ['59759', 'Whitehall MT', '45.9', '-112.2', '3643', '8', '0.86', '165.4', '50.6']
# ['59840', 'Hamilton MT', '46.2', '-114.2', '13052', '28', '0.88', '204.7', '33.7']
# ['83338', 'Jerome ID', '42.7', '-114.3', '19782', '72', '0.93', '137.5', '40.1']
# ['83352', 'Shoshone ID', '43.0', '-114.4', '3330', '15', '0.77', '118.6', '41.1']
# ['83501', 'Lewiston ID', '46.2', '-116.9', '34230', '127', '0.94', '167.4', '46.0']
# ['83605', 'Caldwell ID', '43.66', '-116.65', '39649', '1423', '0.91', '98.1', '37.7']
# ['83617', 'Emmett ID', '44.0', '-116.5', '15422', '66', '0.91', '144.5', '42.4']
# ...

# %%
import matplotlib.pyplot as plt

# %%
names = ['Cas, MT', 'Hel, MT', 'Boz, MT','Ham MT','Jer ID','Sho ID']
values = [1831, 29283, 31567, 3643, 13052, 19782] 

plt.figure(figsize=(40, 10))

plt.subplot(131)
plt.bar(names, values)
plt.suptitle('Categorical Plotting')
plt.show()

# %%
names = ['Cas, MT', 'Hel, MT', 'Boz, MT','Ham MT']
values = [1831, 29283, 31567, 3643,] 

plt.figure(figsize=(10, 3))

plt.subplot(132)
plt.scatter(names, values)
plt.suptitle('Categorical Plotting')
plt.show()

# %%
names = ['Cas, MT', 'Hel, MT', 'Boz, MT']
values = [1831, 29283, 31567]

plt.figure(figsize=(10, 3))

plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Categorical Plotting')
plt.show()

# %%
import os
import csv

# %%
import matplotlib.pyplot

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import scipy.stats

# %%
input_dir= 'C:/Users/veronikalubeck/Desktop/Data'

# %%
os.chdir('/Users/veronikalubeck/Desktop/Data')
data=pd.read_csv('practice_lighting.csv')

# %%
os.getcwd()
# Out:
# '/Users/veronikalubeck/Desktop/Data'

# %%
#plot distribution 

fig=plt.figure(figsize=(8,5))
ax=plt.gca()
ax.hist(data.Wattage,bins=50,label='Empirical Histogram')
plt.xlim([0,200])
ax.tick_params(axis='both',which='major',labelsize=14)
ax.set_ylim([0,55000])
ax.grid()
ax.set_xlabel(r'Wattage', fontsize=14)
ax.set_ylabel('Count', c='CO', fontsize=14)
ax.tick_params(axis='y', colors = "CO")
plt.tight_layout()
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-31-3919cc2fbb7d> in <module>()
#       3 fig=plt.figure(figsize=(8,5))
#       4 ax=plt.gca()
# ----> 5 ax.hist(data.Wattage,bins=50,label='Empirical Histogram')
#       6 plt.xlim([0,200])
#       7 ax.tick_params(axis='both',which='major',labelsize=14)
#
# /Users/veronikalubeck/opt/anaconda2/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1865                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1866                         RuntimeWarning, stacklevel=2)
# -> 1867             return func(ax, *args, **kwargs)
#    1868
#    1869         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /Users/veronikalubeck/opt/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in hist(***failed resolving arguments***)
#    6637             # this will automatically overwrite bins,
#    6638             # so that each histogram uses the same bins
# ...
